# %% [markdown]
# # Интернет-магазин "Стримчик". Анализ популярности продоваемых продуктов

# %% [markdown]
# ## Описание данных

# %% [markdown]
# В данном проекте нам предстоит выявить определяющие закономерности успешности игры. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. Нужно проанализировать поведение клиентов интернет-магазина "Стримчик". Нам доступны данные за прошедший год (2016), а прогнозы сделать на следующий год.
#
# Описание данных:
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Нам необходимо исследовать игры с разных сторон, определить самые популярные жанры и платформы для разных регионов, изучить, как влияют на продажи оценки критиков и пользователей.

# %% [markdown]
# План проектра:
# * Обзор данных
# * Подготовка данных к анализу
# * Анализ данных
# * Проверка гипотез

# %% [markdown]
# ## Обзор данных

# %%
import pandas as pd
from scipy import stats as st
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from io import BytesIO
import requests

# %%
#df_games = pd.read_csv('/datasets/games.csv')

spreadsheet_id = '1I0WVkbFtKxzYXbKRvoW2qyC7nk1XIPOITG_ZqI_7LPg'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
df_games = pd.read_csv(BytesIO(r.content))

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_games.info()
df_games.tail(20)
df_games.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# ## Подготовка данных к анализу

# %% [markdown]
# В данной части нашей работы мы приступаем к обработке таблицы и ее данных:
# * Меняем названия столбцов
# * Приводим данные к нужным типам
# * Выщитываем дополнительные параметры (если нужно)
# * Ищем пропуски и дубликаты

# %%
df_games.columns = ['name', 'platform', 'year_of_release', 'genre', 'NA_sales', 'EU_sales', 'JP_sales', 'other_sales', 'critic_score', 'user_score', 'rating']

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df_games['year_of_release'] = df_games['year_of_release'].fillna(3000) # так как в столбце с "годом выпуска" есть пропуски, я решил, что удалить все строки будет как то не хорошо, по этому заменил их "невозможным" значением
df_games['year_of_release'] = df_games['year_of_release'].astype('int')

# %%
df_games.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release       0
# genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df_games.duplicated().sum()
# Out:
# 0

# %%
df_games.dropna(subset = ['name'], inplace = True)
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   NA_sales         16713 non-null  float64
#  5   EU_sales         16713 non-null  float64
#  6   JP_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int32(1), object(5)
# memory usage: 1.5+ MB

# %%
df_games['user_score'].value_counts()
df_games.query('user_score == "tbd"')
# Out:
#                                                     name platform  \
# 119                                        Zumba Fitness      Wii
# 301                       Namco Museum: 50th Anniversary      PS2
# 520                                      Zumba Fitness 2      Wii
# 645                                         uDraw Studio      Wii
# 657             Frogger's Adventures: Temple of the Frog      GBA
# 718                                      Just Dance Kids      Wii
# 726                            Dance Dance Revolution X2      PS2
# 821                                      The Incredibles      GBA
# 881                        Who wants to be a millionaire       PC
# 1047                                       Tetris Worlds      GBA
# 1048                                    Imagine: Teacher       DS
# 1069                              Personal Trainer: Math       DS
# 1070                                        Game Party 3      Wii
# 1089                                      Monsters, Inc.      GBA
# 1151                   SpongeBob's Atlantis SquarePantis       DS
# 1199                                      MySims Kingdom       DS
# 1210                        Moshi Monsters: Moshling Zoo       DS
# 1284                            Disney Sing It: Pop Hits      Wii
# 1291                                Imagine: Master Chef       DS
# 1292                                     Disney Princess      GBA
# 1298                     The SpongeBob SquarePants Movie      GBA
# 1300                             Midway Arcade Treasures      PS2
# 1309                                              Wall-E       DS
# 1341                     Disney Princess: Magical Jewels       DS
# 1367                                   Hello Kitty Party       DS
# 1423                                       SingStar Abba      PS2
# 1487                         Petz Wild Animals: Dolphinz       DS
# 1541                           Imagine: Wedding Designer       DS
# 1560                     Mystery Case Files: MillionHeir       DS
# 1700                                      Disney Sing It      Wii
# 1707       LEGO Indiana Jones 2: The Adventure Continues       DS
# 1778                                         Action Bass       PS
# 1803                     EA Sports Active: More Workouts      Wii
# 1862                                       NBA Live 2001      PS2
# 1863                                    SingStar Legends      PS2
# 1871                                         Petz Dogz 2       DS
# 1888                  LEGO Star Wars III: The Clone Wars       DS
# 1894                                Imagine: Babysitters       DS
# 1896                               Fisherman's Bass Club      PS2
# 1917                  Imagine: Fashion Designer New York       DS
# 1929                                       MySims Agents       DS
# 1969          Dora the Explorer: Dora Saves the Mermaids       DS
# 1988                              ATV: Quad Power Racing       PS
# 2017                                Junior Brain Trainer       DS
# 2020                                         ZhuZhu Pets       DS
# 2043   Disney Fairies: Tinker Bell and the Lost Treasure       DS
# 2071                                    NFL GameDay 2001       PS
# 2092                                   Cars: Race-O-Rama      Wii
# 2093                                  Puzzler Collection       DS
# 2096                           Littlest Pet Shop: Winter       DS
# 2120                Tamagotchi Connection: Corner Shop 2       DS
# 2157                                    Wheel of Fortune      PS2
# 2179                                     Just Dance 2016      Wii
# 2180                               Skylanders: Trap Team      Wii
# 2234                        SnoCross Championship Racing       PS
# 2244                                                Cars      Wii
# 2245                          Monster High: Ghoul Spirit       DS
# 2269                                     Nickelodeon Fit      Wii
# 2281                                        Namco Museum       XB
# 2312       LEGO Pirates of the Caribbean: The Video Game       DS
# 2315                               Skylanders: Trap Team     X360
# 2320                                          Madagascar      GBA
# 2322                 The Biggest Loser: Ultimate Workout     X360
# 2330                                       TouchMaster 2       DS
# 2403                                    Triple Play 2002      PS2
# 2411                                       SingStar '90s      PS2
# 2412                            Wizards of Waverly Place       DS
# 2426                                          Pictionary      Wii
# 2439                           Gold's Gym: Dance Workout      Wii
# 2459                                   Petz Dogz Fashion       DS
# 2460                             ATV Quad Power Racing 2      PS2
# 2512                             Karaoke Revolution Glee      Wii
# 2513                                    I Spy: Fun House       DS
# 2524                      Ready 2 Rumble Boxing: Round 2      PS2
# 2527                                  Imagine: Rock Star       DS
# 2550              Final Fantasy XI: Wings of the Goddess      PS2
# 2553                                     SingStar Vol. 2      PS3
# 2565                                       Deca Sports 2      Wii
# 2573                          Hasbro Family Game Night 3      Wii
# 2589                  EA Sports Active NFL Training Camp      Wii
# 2595                  Dance Dance Revolution SuperNOVA 2      PS2
# 2617           Secret Agent Barbie: Royal Jewels Mission      GBA
# 2652                                 ABBA: You Can Dance      Wii
# 2658                                       Puzzler World       DS
# 2671                           Personal Trainer: Walking       DS
# 2675                                 Tetris Party Deluxe       DS
# 2678                                        My Baby Girl       DS
# 2733                                          Deer Drive      Wii
# 2757                              Sega Superstars Tennis       DS
# 2765                           Tiger Woods PGA Tour 2001      PS2
# 2786                         Madagascar: Escape 2 Africa       DS
# 2814                Beyblade VForce: Ultimate Blader Jam      GBA
# 2823                          Imagine: Interior Designer       DS
# 2826                                     Rabbids Go Home       DS
# 2843                                 Jampack Winter 2001      PS2
# 2871                                 Super Trucks Racing      PS2
# 2873                      Jeremy McGrath Supercross 2000       PS
# 2878                    Scooby-Doo 2: Monsters Unleashed      GBA
# 2908                                     Madden NFL 2005       GC
# 2909                                         F-14 Tomcat      GBA
# 2914                                      FIFA Soccer 11       DS
# 2924                           Hannah Montana: The Movie       DS
# 2933                             Disney's Chicken Little      GBA
# 2971                                        World of Zoo       DS
# 2993                        LEGO Harry Potter: Years 1-4      PSP
# 2994                           Midway Arcade Treasures 2      PS2
# 3028                           Pro Pinball: Big Race USA       PS
# 3038                                       Country Dance      Wii
# 3046                                        Finding Nemo       XB
# 3048                                          Lalaloopsy       DS
# 3050                                          Madagascar       GC
# 3056                                  TV Show King Party      Wii
# 3058          Strawberry Shortcake: Summertime Adventure      GBA
# 3077           Disney's Kim Possible 2: Drakken's Demise      GBA
# 3081                        LEGO Harry Potter: Years 5-7       DS
# 3092                        The Biggest Loser: Challenge      Wii
# 3117                                  MX vs. ATV Untamed      PSP
# 3122                                              Wall-E      PSP
# 3124                                       Crafting Mama       DS
# 3158                                                  Up       DS
# 3160          Konami Collector's Series: Arcade Advanced      GBA
# 3174                                      SingStar Queen      PS2
# 3176                          Disney Sing It: Party Hits      Wii
# 3215                                        Namco Museum       GC
# 3217                     Cabela's Big Game Hunter (2008)      Wii
# 3228                           Family Feud: 2010 Edition      Wii
# 3238                           The Princess and the Frog       DS
# 3244      Disney's 102 Dalmatians: Puppies to the Rescue       PS
# 3281                      The Black Eyed Peas Experience      Wii
# 3308                                     Madden NFL 2003      GBA
# 3314                                     Madden NFL 2002       GC
# 3321                        Cabela's Monster Buck Hunter      Wii
# 3324                                      Monster Trucks      GBA
# 3349                                    NASCAR Heat 2002      PS2
# 3360                           Littlest Pet Shop: Garden       DS
# 3368                                   Wipeout: The Game       DS
# 3372                           Major League Baseball 2K7      PS2
# 3377                                  New Carnival Games      Wii
# 3379                           Littlest Pet Shop: Jungle       DS
# 3389                                      NFL Blitz 2001       PS
# 3409                         Disney Sing It: Family Hits      Wii
# 3427   SpongeBob SquarePants featuring Nicktoons: Glo...      PS2
# 3429       LEGO Indiana Jones 2: The Adventure Continues      PSP
# 3487                                    NCAA Football 10      PS2
# 3491                            Hasbro Family Game Night      PS2
# 3500                                         Petz Dogz 2      Wii
# 3504                       Cabela's Dangerous Hunts 2011      Wii
# 3520                                     Rapala: We Fish      Wii
# 3523                                 Jampack Summer 2002      PS2
# 3536                                     Trivial Pursuit      Wii
# 3545                                        Bratz 4 Real       DS
# 3553                           Petz Wild Animals: Tigerz       DS
# 3555                            Ms. Pac-Man Maze Madness      GBA
# 3567                             Harry Potter Collection      PS2
# 3572                                 Knockout Kings 2001      PS2
# 3574                                         Petz Dogz 2      PS2
# 3580             Jillian Michaels Fitness Ultimatum 2010      Wii
# 3644                                         Contender 2       PS
# 3673                Barbie Horse Adventures: Riding Camp       DS
# 3677                                      Petz Catz Clan       DS
# 3678             ZhuZhu Pets 2: Featuring The Wild Bunch       DS
# 3689   Are You Smarter than a 5th Grader? Make the Grade      Wii
# 3730          Phineas and Ferb: Across the 2nd Dimension       DS
# 3731                                    50 Classic Games       DS
# 3735                                        Petz Nursery       DS
# 3751                          Monster High: Ghoul Spirit      Wii
# 3773                    Monster Jam: Path of Destruction      Wii
# 3786                        Hello Kitty: Big City Dreams       DS
# 3792                                  Jewel Master Egypt       DS
# 3796                  Are You Smarter Than A 5th Grader?       DS
# 3801                            How to Train Your Dragon       DS
# 3833               Guinness World Records: The Videogame       DS
# 3839                      Ready 2 Rumble Boxing: Round 2       PS
# 3849                                     Swing Away Golf      PS2
# 3855               That's So Raven 2: Supernatural Style      GBA
# 3881                                  Classic Word Games       DS
# 3922                               Petz: Hamsterz Life 2       DS
# 3923                            World Championship Poker       XB
# 3932                                       My Word Coach      Wii
# 3937   The Adventures of Jimmy Neutron Boy Genius: At...      GBA
# 3940                                 Monsters vs. Aliens       DS
# 3947                             Tiger Woods PGA Tour 07      PS3
# 3952                       Cars Toon: Mater's Tall Tales      Wii
# 3955                                      Disney Sing It      PS2
# 3981                            Rooms: The Main Building       DS
# 4002                    Nicktoons: Attack of the Toybots      PS2
# 4012                           Tony Hawk's Underground 2      GBA
# 4018                                            NBA 2K11      Wii
# 4021                                    Babysitting Mama      Wii
# 4028                                  The Price is Right       DS
# 4041                         Dreamworks Madagascar Kartz      Wii
# 4061                                     Pac-Man World 2       XB
# 4074                       Madagascar: Operation Penguin      GBA
# 4083                                      Ultimate I Spy      Wii
# 4100                                    NCAA Football 09      PS2
# 4104                     Rayman Raving Rabbids: TV Party       DS
# 4113      Bakugan Battle Brawlers: Defenders of the Core       DS
# 4122                                                  Up      PS2
# 4124                                 Jake Power: Fireman       DS
# 4138                                 Alice in Wonderland       DS
# 4150                                   Cars: Race-O-Rama       DS
# 4160                              Clash of Elementalists       DS
# 4185                                   Cars: Race-O-Rama      PS2
# 4190                      Active Life: Extreme Challenge      Wii
# 4192                           Spider-Man: Friend or Foe       DS
# 4199                   Kong: The 8th Wonder of the World      GBA
# 4210                                          Iridion 3D      GBA
# 4212                         Classic NES Series: Pac-Man      GBA
# 4223                             Razor Freestyle Scooter       PS
# 4230                                     Stuart Little 2      GBA
# 4231                          Tak 2: The Staff of Dreams      GBA
# 4232                                      SingStar Amped      PS2
# 4236                                          Scooby-Doo      GBA
# 4251                        Crayola: Treasure Adventures       DS
# 4255                          WWE SmackDown vs. Raw 2011      Wii
# 4263                           The Princess and the Frog      Wii
# 4284                      NASCAR 2005: Chase for the Cup       XB
# 4292               American Girl: Kit Mystery Challenge!       DS
# 4293                                     Country Dance 2      Wii
# 4297                           Nickelodeon Team Umizoomi       DS
# 4305                       Barbie as The Island Princess      Wii
# 4307                                              iCarly      Wii
# 4317                                ATV Offroad Fury Pro      PSP
# 4335                   Hot Wheels: Stunt Track Challenge      GBA
# 4341                                      Bee Movie Game       DS
# 4355                             ATV Quad Power Racing 2       XB
# 4376                       Discovery Kids: Kitten Corner       DS
# 4377                        Rock Band Country Track Pack      Wii
# 4379                               Brunswick Pro Bowling     X360
# 4416                   Family Fest Presents Circus Games      Wii
# 4429                           Puppy Luv: Spa and Resort       DS
# 4436                          Scooby-Doo! Mystery Mayhem      GBA
# 4448                               Power Rangers: S.P.D.      GBA
# 4460                   SpongeBob's Atlantis SquarePantis      PS2
# 4463                                  Karaoke Revolution      Wii
# 4476                                  Master of Illusion       DS
# 4477                            Spec Ops: Covert Assault       PS
# 4503                                    My Spanish Coach       DS
# 4523                                       TouchMaster 3       DS
# 4527                         Barbie: Groom and Glam Pups       DS
# 4529                                         Petz Bunnyz       DS
# 4532                                          Deer Drive       DS
# 4533                                      Petz: Horsez 2       DS
# 4537                             Midway Arcade Treasures       XB
# 4539                  Remington Great American Bird Hunt      Wii
# 4568                  Ben 10 Alien Force: Vilgax Attacks       DS
# 4574                  Ben 10 Alien Force: Vilgax Attacks      PSP
# 4588          Star Wars Trilogy: Apprentice of the Force      GBA
# 4594                            Just Dance: Summer Party      Wii
# 4599                                      Petz: Horsez 2      Wii
# 4617                       Cabela's Legendary Adventures      PS2
# 4647                                 High Rollers Casino      PS2
# 4652              Star Wars Starfighter: Special Edition       XB
# 4662                                    Wheel of Fortune       DS
# 4669                                    MLB 10: The Show      PS2
# 4674                                  Cool Boarders 2001       PS
# 4696             JumpStart: Escape from Adventure Island      Wii
# 4701                                   Cars: Race-O-Rama      PSP
# 4714                                          The Smurfs       DS
# 4718   James Patterson Women's Murder Club: Games of ...       DS
# 4724                                            NBA 2K11      PS2
# 4732                                                  Up      PSP
# 4764                                   Just Dance Kids 2     X360
# 4769           Star Wars The Clone Wars: Republic Heroes      PSP
# 4775                                    NFL GameDay 2003      PS2
# 4785             The Incredibles: Rise of the Underminer      GBA
# 4790                         Power Rangers: Dino Thunder       GC
# 4794                             SpongeBob SquigglePants      Wii
# 4811                              Hot Wheels: Beat That!      PS2
# 4814                               Brunswick Pro Bowling      PS2
# 4823                                 Style Lab: Makeover       DS
# 4828                      Nicktoons: Freeze Frame Frenzy      GBA
# 4829                               Monster Trucks Mayhem      Wii
# 4831                        Rapala Pro Bass Fishing 2010     X360
# 4841                 Winter Sports 2: The Next Challenge      Wii
# 4845                Moshi Monsters: Moshlings Theme Park       DS
# 4862                                   Littlest Pet Shop      Wii
# 4869                                         NASCAR Heat       PS
# 4870                                           Planet 51       DS
# 4876                               Disney's Brother Bear      GBA
# 4891                                 Ener-G: Gym Rockets       DS
# 4895   Are You Smarter than a 5th Grader? Make the Grade       DS
# 4921                          Monster Jam: Urban Assault       DS
# 4928              Disney Princess: Enchanting Storybooks      Wii
# 4942                             Tiger Woods PGA Tour 08      PS2
# 4947    Karaoke Revolution Presents American Idol Encore      PS2
# 4951      SpongeBob vs The Big One: Beach Party Cook Off       DS
# 4982                                             Ice Age      GBA
# 4990                                Junior Classic Games       DS
# 5004                                    NCAA Football 11      PS2
# 5012                Tamagotchi Connection: Corner Shop 3       DS
# 5013                                        Silent Scope      PS2
# 5015     Dora The Explorer: Dora Saves the Snow Princess      PS2
# 5030                      Ice Age: Dawn of the Dinosaurs       DS
# 5034            Sesame Street: Elmo's A-to-Zoo Adventure      Wii
# 5035                                          Iron Man 2      PSP
# 5044                             Tiger Woods PGA Tour 08      PSP
# 5046                           Petz Rescue: Wildlife Vet       DS
# 5049                                       Madden NFL 11      PSP
# 5061                                        Puppy Palace       DS
# 5069                           Petz Rescue: Ocean Patrol       DS
# 5078                               NBA Inside Drive 2002       XB
# 5081                  LEGO Star Wars III: The Clone Wars      PSP
# 5084                                        Petz: Catz 2      PS2
# 5090                    Monster Jam: Path of Destruction       DS
# 5100                                      Rec Room Games      Wii
# 5106                       Cabela's Big Game Hunter 2012      Wii
# 5126                              Imagine: Salon Stylist       DS
# 5168     Build-A-Bear Workshop: A Friend Fur All Seasons      Wii
# 5169                         Dreamworks Madagascar Kartz       DS
# 5198                                    NFL GameDay 2001      PS2
# 5207                      Shaun Palmer's Pro Snowboarder      GBA
# 5208                 North American Hunting Extravaganza      Wii
# 5209               ZhuZhu Pets: Featuring The Wild Bunch      Wii
# 5242                               Digging for Dinosaurs       DS
# 5253                        Press Your Luck 2010 Edition      Wii
# 5265                                       Outlaw Golf 2      PS2
# 5269               Disney's Tarzan: Return to the Jungle      GBA
# 5299   The Adventures of Jimmy Neutron Boy Genius: Je...      GBA
# 5304                                    Xbox Music Mixer       XB
# 5308                                   College Hoops 2K8      PS2
# 5318                              The Tale of Despereaux      PS2
# 5333                               Rugrats: Royal Ransom      PS2
# 5344                          The Wild Thornberrys Movie      GBA
# 5346                           Hannah Montana: The Movie      Wii
# 5354                     Classic NES Series: Ice Climber      GBA
# 5355            Pirates of the Caribbean: At World's End       DS
# 5370                                   Super Bust-A-Move      PS2
# 5381                                DanceDanceRevolution      Wii
# 5409                             Smart Girl's Party Game       DS
# 5410                                          Spy Hunter       XB
# 5421                                         My Baby Boy       DS
# 5425                                 Imagine: Movie Star       DS
# 5432   World Championship Poker 2: Featuring Howard L...      PS2
# 5436                                          Iron Man 2       DS
# 5443                                         Bejeweled 3       DS
# 5452      Night at the Museum: Battle of the Smithsonian       DS
# 5462                            Disney's Treasure Planet      PS2
# 5463                                 NASCAR Thunder 2002       XB
# 5469                                            Bookworm       DS
# 5474                                     Shrek SuperSlam      GBA
# 5477       LEGO Pirates of the Caribbean: The Video Game      PSP
# 5483                                  Cool Boarders 2001      PS2
# 5488                      GT Advance Championship Racing      GBA
# 5503      Night at the Museum: Battle of the Smithsonian      Wii
# 5515                 Capcom Classics Collection Reloaded      PSP
# 5516                               NCAA GameBreaker 2001       PS
# 5531                                     Def Jam Rapstar      Wii
# 5535                                         NBA Live 06       GC
# 5537                           Dr. Mario / Puzzle League      GBA
# 5538             Family Party: 90 Great Games Party Pack      Wii
# 5547                      Discovery Kids: Puppy Playtime       DS
# 5549        Teenage Mutant Ninja Turtles 2: Battle Nexus      GBA
# 5550                                   Nicktoons: Movin'      PS2
# 5552                                        Chicken Riot      Wii
# 5557                                  NCAA Basketball 10     X360
# 5562                           Style Lab: Jewelry Design       DS
# 5570                            Bratz: Girlz Really Rock       DS
# 5571                                    Minute to Win It     X360
# 5599           Ben 10 Ultimate Alien: Cosmic Destruction       DS
# 5600                                      Pony Friends 2       DS
# 5601                                My Baby: First Steps       DS
# 5613                                            Fortress      GBA
# 5614   Disney Fairies: Tinker Bell and the Great Fair...       DS
# 5617                               Power Rangers Samurai      Wii
# 5618   Karaoke Revolution Presents American Idol Enco...      Wii
# 5635                                           Wipeout 2      Wii
# 5639                        Rock Band Country Track Pack      PS2
# 5654                                     Sega Smash Pack      GBA
# 5660                                     Madden NFL 2002      GBA
# 5661                           Bigfoot: Collision Course      Wii
# 5663                       Cabela's Dangerous Hunts 2011     X360
# 5667                                   The Biggest Loser       DS
# 5668                               Power Rangers Samurai       DS
# 5670                                       4x4 Evolution      PS2
# 5676                               Goosebumps HorrorLand       DS
# 5678                     Littlest Pet Shop: City Friends       DS
# 5685                                     Chicken Blaster      Wii
# 5697                                     Shrek the Third      PSP
# 5725                                    1001 Touch Games       DS
# 5727                        Namco Museum: Virtual Arcade     X360
# 5754                                        7 Wonders II       DS
# 5768                       Barbie as The Island Princess       DS
# 5777                            Shaun White Snowboarding      PS2
# 5781                                    MySims SkyHeroes       DS
# 5786                                 The Incredible Hulk      Wii
# 5799                                         Music Maker      PS2
# 5806                    Calvin Tucker's Redneck Jamboree      Wii
# 5810                                           Math Play       DS
# 5841                            Karaoke Revolution Party      PS2
# 5843                  Lizzie McGuire 3: Homecoming Havoc      GBA
# 5857         The Dukes of Hazzard II: Daisy Dukes It Out       PS
# 5867                            Looney Tunes: Duck Amuck       DS
# 5872                                  Hard Hitter Tennis      PS2
# 5881                                               Jonas       DS
# 5904                              Imagine: Family Doctor       DS
# 5912             Finding Nemo: The Continuing Adventures      GBA
# 5913                    Spirit: Stallion of the Cimarron      GBA
# 5916                                        MySims Party       DS
# 5919                                          Shark Tale       GC
# 5921                                           Squinkies       DS
# 5922                        Rapala Pro Bass Fishing 2010      Wii
# 5941                         Dreamworks Madagascar Kartz      PS3
# 5944                         Phineas and Ferb Ride Again       DS
# 5953        Lupin the 3rd: Treasure of the Sorcerer King      PS2
# 5959                Nicktoons: Battle for Volcano Island       DS
# 5983             Alvin and the Chipmunks: The Squeakquel       DS
# 5991                Imagine: Fashion Designer World Tour       DS
# 5997                                TouchMaster: Connect       DS
# 6010                             Marvel Super Hero Squad      PS2
# 6011                John Deere: Harvest in the Heartland       DS
# 6033                                Shrek: Forever After      Wii
# 6036                   Karaoke Revolution Glee: Volume 3      Wii
# 6040                         Mah Jong Quest: Expeditions       DS
# 6046           Sesame Street: Cookie's Counting Carnival      Wii
# 6054                                           Surf's Up      PS2
# 6055                                 Looney Tunes Racing       PS
# 6067                            Neopets Puzzle Adventure       DS
# 6073                                           Purr Pals      Wii
# 6084                                  Bratz: Super Babyz       DS
# 6087                                    SingStar Country      PS2
# 6091                    Disney's Extreme Skate Adventure      GBA
# 6104                          X-Men: Reign of Apocalypse      GBA
# 6120                                All Star Cheer Squad       DS
# 6124                                           Baby Pals       DS
# 6126                                         Bratz Ponyz       DS
# 6128                              Junior Brain Trainer 2       DS
# 6146                Hannah Montana: Spotlight World Tour      PS2
# 6148                            Carol Vorderman's Sudoku      PS2
# 6160                        Pitfall: The Mayan Adventure      GBA
# 6163           Ben 10 Ultimate Alien: Cosmic Destruction      Wii
# 6167                            Disney's Treasure Planet      GBA
# 6177                      Disney Channel: All Star Party      Wii
# 6180   The Chronicles of Narnia: The Lion, The Witch ...       GC
# 6184                                            Corvette      GBA
# 6186                Moshi Monsters: Moshlings Theme Park      3DS
# 6187                       Cabela's Big Game Hunter 2012     X360
# 6189   The Adventures of Jimmy Neutron Boy Genius: At...       GC
# 6204                                           Real Pool      PS2
# 6206                                 Tom and Jerry Tales       DS
# 6210                                  CSI: Deadly Intent      Wii
# 6213                                          Madagascar       XB
# 6214                             The Smurfs: Dance Party      Wii
# 6226                                           Wappy Dog       DS
# 6228                      Tak and the Guardians of Gross      PS2
# 6231                                  NCAA Basketball 09      PS2
# 6247                               Cabela's Trophy Bucks      PS2
# 6249                            Q-Ball: Billiards Master      PS2
# 6257                           Motocross Maniacs Advance      GBA
# 6268                                     Trivial Pursuit      PS2
# 6287                                         Sydney 2000       PS
# 6288                            Hot Wheels: Track Attack       DS
# 6295                                   NickToons: Racing      GBA
# 6296                          iCarly 2: iJoin The Click!       DS
# 6298                                              EyePet      PSP
# 6301                                             G-Force      PS2
# 6302                Remington Super Slam Hunting: Africa      Wii
# 6308                                      Over the Hedge      GBA
# 6309                                          Wave Rally      PS2
# 6312                             Disney's Chicken Little       GC
# 6327                             Tiger Woods PGA Tour 07      PSP
# 6341                                            Monopoly       DS
# 6345                               Mat Hoffman's Pro BMX      GBA
# 6347                                           Wipeout 2     X360
# 6361                                 NASCAR Thunder 2003       XB
# 6365               Final Fantasy XI: Ultimate Collection     X360
# 6368                                        NFL Street 3      PSP
# 6369                           Pro Evolution Soccer 2013      PSP
# 6373                             Beyblade: Metal Masters       DS
# 6376                    Littlest Pet Shop: Beach Friends       DS
# 6378                               I Spy: Spooky Mansion      Wii
# 6384                                   NBA ShootOut 2001       PS
# 6385                                   Just Dance Kids 2      Wii
# 6387                                        Pinkalicious       DS
# 6393                          Reader Rabbit Kindergarten       DS
# 6397                                   Super Collapse! 3       DS
# 6398                                         Ratatouille     X360
# 6403                                              Boogie       DS
# 6405                           Operation Armored Liberty      GBA
# 6409        Are You Smarter than a 5th Grader? Game Time      Wii
# 6437                    Battle of Giants: Mutant Insects       DS
# 6438                                      Petz: Horsez 2      PS2
# 6455                           Family Feud: 2010 Edition       DS
# 6457                                                Bolt      PS2
# 6458      Marvel Super Hero Squad: The Infinity Gauntlet      Wii
# 6466                          Major League Baseball 2K10      Wii
# 6467   The Adventures of Jimmy Neutron Boy Genius vs....      GBA
# 6474                                 Star Trek: Invasion       PS
# 6476                        LEGO Harry Potter: Years 5-7      PSP
# 6506   Dora the Explorer: Dora Saves the Crystal Kingdom      Wii
# 6508   Dora the Explorer: The Search for Pirate Pig's...      GBA
# 6510                                   Babysitting Mania       DS
# 6511                                  Scene It? Twilight      Wii
# 6515                             Tiger Woods PGA Tour 10      PS2
# 6516                Summer Sports 2: Island Sports Party      Wii
# 6519                              Imagine: Fashion Party      Wii
# 6526                                     Don King Boxing      Wii
# 6529              Frogger's Journey: The Forgotten Relic      GBA
# 6536                                       Bratz Ponyz 2       DS
# 6539                          Littlest Pet Shop: Friends      Wii
# 6540                                          We Cheer 2      Wii
# 6562                              ATV: Quad Power Racing      GBA
# 6575                          The Penguins of Madagascar       DS
# 6588                                 Reload: Target Down      Wii
# 6589                                       Madden NFL 08       DS
# 6599                             Ice Age 2: The Meltdown      GBA
# 6603                               World Series of Poker       XB
# 6609                                       Zoo Resort 3D      3DS
# 6610                              Smart Girl's Playhouse       DS
# 6611      Walt Disney's The Jungle Book: Rhythm N'Groove      PS2
# 6612                                    Triple Play 2002       XB
# 6616                                 Monsters vs. Aliens      Wii
# 6627                          How to Train Your Dragon 2      3DS
# 6637                                  Ben 10 Triple Pack       DS
# 6642                                      Project Runway      Wii
# 6643                                            Scrabble       DS
# 6647                       Midway's Greatest Arcade Hits      GBA
# 6648                            Disney Sing It: Pop Hits      PS3
# 6654                                Golden Nugget Casino      GBA
# 6658                                     Atari Anthology       XB
# 6660                                     Animal Paradise       DS
# 6679                              Beyblade: Metal Fusion       DS
# 6680                                Karaoke Joysound Wii      Wii
# 6681                         Madagascar: Escape 2 Africa     X360
# 6700                                   The Backyardigans       DS
# 6718                               Daisy Fuentes Pilates      Wii
# 6721                                 Petz: Crazy Monkeyz      Wii
# 6723                  Littlest Pet Shop: Country Friends       DS
# 6725                   Cars: Mater-National Championship      PS2
# 6737                             Nickelodeon Party Blast       GC
# 6742                         Marvel: Ultimate Alliance 2      PSP
# 6747                  Butt Ugly Martians: B.K.M. Battles      GBA
# 6755                                              Create      Wii
# 6759                                           Wipeout 2       DS
# 6760                      Classic NES Series: Excitebike      GBA
# 6774               That's So Raven: Psychic on the Scene       DS
# 6780                          Hasbro Family Game Night 3      PS3
# 6803                                   Disney Stitch Jam       DS
# 6833                                   Just Dance Kids 2      PS3
# 6837                     The Price is Right 2010 Edition      Wii
# 6855                             NCAA March Madness 2004       XB
# 6865                         Imagine: Teacher Class Trip       DS
# 6872      Dance Dance Revolution: Disney Channel Edition      PS2
# 6873                                 The Incredible Hulk       DS
# 6882                         Juiced 2: Hot Import Nights       DS
# 6884                                      Cradle of Rome       DS
# 6902                                   Nickelodeon Dance      Wii
# 6905           Ben 10 Ultimate Alien: Cosmic Destruction      PSP
# 6906             Amazing Adventures: The Forgotten Ruins       DS
# 6920   Fallout 3 Game Add-On Pack: Broken Steel and P...     X360
# 6923                        Pictionary: Ultimate Edition     X360
# 6928                        Pictionary: Ultimate Edition      PS3
# 6930                             Tiger Woods PGA Tour 10      PSP
# 6931                                  Imagine: Zookeeper       DS
# 6932                                Dood's Big Adventure      Wii
# 6944        Are You Smarter than a 5th Grader? Game Time       DS
# 6958                                   MX vs. ATV Reflex      PSP
# 6966                       Cabela's Big Game Hunter 2012      PS3
# 6967                                      Hotel for Dogs       DS
# 6977                        Rock Band Country Track Pack     X360
# 6991                               NCAA GameBreaker 2003      PS2
# 6997                         Rocket Power: Beach Bandits       GC
# 6998                            Shaun White Snowboarding       DS
# 7004                                    NHL FaceOff 2001       PS
# 7005                  Cabela's Outdoor Adventures (2009)      PS3
# 7012                  Jewels of the Tropical Lost Island       DS
# 7013    Sherlock Holmes and the Mystery of Osborne House       DS
# 7015                                       Madden NFL 06      GBA
# 7018                           Megamind: Mega Team Unite      Wii
# 7022                          Major League Baseball 2K10      PS2
# 7024                                           Wipeout 2      3DS
# 7036   World Series of Poker 2008: Battle for the Bra...      PS2
# 7053                     Barbie and the Three Musketeers      Wii
# 7054                                       Madden NFL 12      PSP
# 7056                  Disney Princess: Enchanted Journey      PS2
# 7059                              Hot Wheels: Beat That!       DS
# 7079                                       I Love Horses       DS
# 7086                                 Hello Kitty Seasons      Wii
# 7089                                    NCAA Football 09      PSP
# 7093                               NCAA GameBreaker 2004      PS2
# 7098                            Bass Pro Shops: The Hunt      Wii
# 7102                                       Deca Sports 3      Wii
# 7108                                  Big Beach Sports 2      Wii
# 7110                                    NHL FaceOff 2003      PS2
# 7119                                  New Carnival Games       DS
# 7131             Family Party: 30 Great Games Winter Fun      Wii
# 7137                          Zumba Fitness: World Party      Wii
# 7144                            Time Crisis: Crisis Zone      PS2
# 7146           Ben 10 Ultimate Alien: Cosmic Destruction      PS2
# 7151                                           MotoGP 08      PS2
# 7156                                  Petz Monkeyz House       DS
# 7163                   Cloudy With a Chance of Meatballs       DS
# 7168                   Discovery Kids: Dolphin Discovery       DS
# 7179                  Rock Band Track Pack: Classic Rock      Wii
# 7180                    Petz Rescue: Endangered Paradise       DS
# 7181                             Rapala's Fishing Frenzy      Wii
# 7192                      Duel Masters: Kaijudo Showdown      GBA
# 7208                            Neopets Puzzle Adventure      Wii
# 7212                                     All Star Karate      Wii
# 7215                   Naruto Shippuden: Ninja Council 4       DS
# 7217                               Worms: Battle Islands      Wii
# 7222                                      ATV Quad Kings      Wii
# 7224                                       Ultimate Band       DS
# 7229                   Lethal Skies Elite Pilot: Team SW      PS2
# 7237                   Family Fest presents: Movie Games      Wii
# 7250                                  Imagine: Detective       DS
# 7260                      Wreckless: ThE YaKuza MisSiOns      PS2
# 7263                               CSI: Fatal Conspiracy      Wii
# 7268                            Hasbro Family Game Night       DS
# 7270                    Samurai Jack: The Amulet of Time      GBA
# 7288                         G.I. Joe: The Rise of Cobra      Wii
# 7289                            Jewel Quest: Expeditions       DS
# 7292      Marvel Super Hero Squad: The Infinity Gauntlet       DS
# 7295                                         Dark Summit      PS2
# 7299                                        MySims Party      Wii
# 7304                      Namco Museum: 50th Anniversary       GC
# 7310                                   Big League Sports     X360
# 7311                           Petz Rescue: Wildlife Vet      Wii
# 7320                             Bratz: Forever Diamondz       GC
# 7321                               NCAA March Madness 08     X360
# 7325                                    Wild Wild Racing      PS2
# 7336                                    Petz: Horse Club      Wii
# 7341       Harry Potter and the Deathly Hallows - Part 2       DS
# 7342                                       Puss in Boots      Wii
# 7357                       LEGO Ninjago: Shadow of Ronin      3DS
# 7370                             Imagine: Boutique Owner       DS
# 7381                            Bratz: Girlz Really Rock      Wii
# 7384            The Chronicles of Narnia: Prince Caspian       DS
# 7390                        The Magic School Bus: Oceans       DS
# 7406                             DanceDanceRevolution II      Wii
# 7414                 Hidden Mysteries: Buckingham Palace       DS
# 7437                                Shrek: Reekin' Havoc      GBA
# 7445                             Marvel Super Hero Squad      PSP
# 7459                                  Tony Hawk's Motion       DS
# 7460                                     Disney's Planes       DS
# 7472                                    NCAA Football 10      PSP
# 7484                                       Outlaw Golf 2       XB
# 7490                       Discovery Kids: Pony Paradise       DS
# 7496                         Barbie: Groom and Glam Pups      Wii
# 7498               Mary-Kate and Ashley: Girls Night Out      GBA
# 7500                                        Wedding Dash       DS
# 7503                            World Championship Cards      PSP
# 7509                                    NASCAR Heat 2002       XB
# 7537                                  Bratz: Rock Angelz       GC
# 7560                 Jillian Michaels' Fitness Adventure     X360
# 7567                                                Cars       XB
# 7569                                          Spy Hunter       GC
# 7574                            Super Dodge Ball Advance      GBA
# 7586             Ni Hao, Kai-lan: New Year's Celebration       DS
# 7587                  Rock Band Track Pack: Classic Rock      PS2
# 7598                                NCAA Final Four 2004      PS2
# 7619                                      Treasure World       DS
# 7622                                Ford Racing Off Road      PS2
# 7623                      Namco Museum: 50th Anniversary      GBA
# 7625                                          The BIGS 2      PS2
# 7628                             Mat Hoffman's Pro BMX 2       XB
# 7634                        Press Your Luck 2010 Edition       DS
# 7637                  Cabela's North American Adventures      Wii
# 7638                Wizards of Waverly Place: Spellbound       DS
# 7640                     Cabela's Big Game Hunter (2008)      PS2
# 7641              The Cheetah Girls: Passport to Stardom       DS
# 7645                                          Shark Tale       XB
# 7646                                        NFL Street 2       GC
# 7660                      Tetris Worlds (Online Edition)       XB
# 7667                            Looney Tunes: Space Race      PS2
# 7669                                  Neighborhood Games      Wii
# 7670                                     Backyard Hockey      GBA
# 7681                                         Ratatouille      GBA
# 7704                                      Shutter Island       PC
# 7720   Chronicles of Mystery: Curse of the Ancient Te...       DS
# 7734                  Iron Chef America: Supreme Cuisine       DS
# 7737                             Ice Age 2: The Meltdown       GC
# 7740                    Dinotopia: The Timestone Pirates      GBA
# 7742                           Petz Pony: Beauty Pageant       DS
# 7754                                         Dream Salon       DS
# 7756                       We Wish You A Merry Christmas      Wii
# 7758                        Rock Band Country Track Pack      PS3
# 7761                           Just Dance: Greatest Hits      Wii
# 7776   Are You Smarter Than a 5th Grader? Back to School      Wii
# 7781                  IHRA Professional Drag Racing 2005      PS2
# 7783                          101-in-1 Explosive Megamix       DS
# 7786                                  Scene It? Twilight       DS
# 7787                            Trivial Pursuit unhinged      PS2
# 7793                     Silent Scope 2: Dark Silhouette      PS2
# 7794                           The Spiderwick Chronicles      Wii
# 7795                          Dave Mirra Freestyle BMX 2      GBA
# 7801               Marvel Super Hero Squad: Comic Combat      PS3
# 7813                          SNK Arcade Classics Vol. 1      PS2
# 7818                                   The Polar Express      GBA
# 7823               Frogger's Adventures 2: The Lost Wand      GBA
# 7829                            Hot Wheels: Track Attack      Wii
# 7841                Barbie Horse Adventures: Riding Camp      PS2
# 7844                                          SSX Tricky      GBA
# 7848                                         Pet Zombies      3DS
# ...
# 14873         0.00           NaN        tbd    NaN
# 14879         0.00          57.0        tbd   E10+
# 14886         0.00           NaN        tbd      E
# 14900         0.00           NaN        tbd      E
# 14903         0.00           NaN        tbd      E
# 14916         0.00          31.0        tbd   E10+
# 14918         0.00           NaN        tbd      E
# 14923         0.00           NaN        tbd   E10+
# 14925         0.00          60.0        tbd      E
# 14936         0.00          57.0        tbd   E10+
# 14938         0.00           NaN        tbd      E
# 14942         0.00           NaN        tbd      E
# 14943         0.00           NaN        tbd      E
# 14944         0.00           NaN        tbd      E
# 14952         0.00          69.0        tbd      E
# 14953         0.00          73.0        tbd      E
# 14966         0.00           NaN        tbd      E
# 14976         0.00           NaN        tbd      E
# 14978         0.00           NaN        tbd      E
# 14982         0.00          70.0        tbd      M
# 15006         0.00          62.0        tbd      E
# 15010         0.00           NaN        tbd      E
# 15016         0.00           NaN        tbd      E
# 15019         0.00           NaN        tbd      E
# 15021         0.00          67.0        tbd   E10+
# 15025         0.00           NaN        tbd      E
# 15030         0.00           NaN        tbd      T
# 15032         0.00           NaN        tbd      E
# 15036         0.00           NaN        tbd    NaN
# 15048         0.00          58.0        tbd      E
# 15050         0.00          53.0        tbd      E
# 15056         0.00           NaN        tbd      E
# 15060         0.00          73.0        tbd      E
# 15068         0.00          66.0        tbd   E10+
# 15072         0.00           NaN        tbd   E10+
# 15075         0.00          80.0        tbd      E
# 15080         0.00          71.0        tbd      E
# 15087         0.00           NaN        tbd      T
# 15089         0.00           NaN        tbd      E
# 15093         0.00           NaN        tbd      E
# 15096         0.00          71.0        tbd      E
# 15104         0.00          66.0        tbd      T
# 15106         0.00          63.0        tbd      T
# 15125         0.00           NaN        tbd      E
# 15126         0.00          47.0        tbd      E
# 15129         0.00           NaN        tbd      T
# 15134         0.00          60.0        tbd      E
# 15135         0.00          60.0        tbd      E
# 15138         0.00           NaN        tbd      E
# 15141         0.00           NaN        tbd   E10+
# 15142         0.00           NaN        tbd      E
# 15151         0.00          73.0        tbd      E
# 15162         0.00           NaN        tbd      E
# 15173         0.00          67.0        tbd      E
# 15179         0.00          49.0        tbd      T
# 15187         0.00           NaN        tbd      E
# 15190         0.00           NaN        tbd      E
# 15202         0.00           NaN        tbd    NaN
# 15205         0.00          58.0        tbd      T
# 15214         0.00          67.0        tbd   E10+
# 15218         0.00           NaN        tbd      E
# 15223         0.00           NaN        tbd      E
# 15225         0.00           NaN        tbd    NaN
# 15243         0.00          71.0        tbd      E
# 15247         0.00          62.0        tbd      T
# 15251         0.00          38.0        tbd      T
# 15267         0.00           NaN        tbd   E10+
# 15270         0.00           NaN        tbd      E
# 15287         0.00           NaN        tbd      E
# 15290         0.00           NaN        tbd      E
# 15292         0.00          60.0        tbd   E10+
# 15294         0.00           NaN        tbd      E
# 15310         0.00          57.0        tbd      E
# 15311         0.00           NaN        tbd      E
# 15316         0.00           NaN        tbd      E
# 15317         0.00           NaN        tbd   E10+
# 15326         0.00           NaN        tbd      E
# 15330         0.00          63.0        tbd   E10+
# 15331         0.00          64.0        tbd   E10+
# 15333         0.00           NaN        tbd      E
# 15335         0.00          68.0        tbd      T
# 15336         0.00           NaN        tbd      E
# 15341         0.00           NaN        tbd      E
# 15348         0.00          50.0        tbd      T
# 15352         0.00           NaN        tbd    NaN
# 15358         0.00          67.0        tbd      T
# 15360         0.00           NaN        tbd      T
# 15364         0.00           NaN        tbd      E
# 15380         0.00           NaN        tbd      E
# 15394         0.00           NaN        tbd   E10+
# 15395         0.00          62.0        tbd      T
# 15397         0.00           NaN        tbd      E
# 15401         0.00           NaN        tbd      E
# 15408         0.00          67.0        tbd      E
# 15412         0.00           NaN        tbd      T
# 15420         0.00          64.0        tbd   E10+
# 15433         0.00          62.0        tbd      E
# 15434         0.00          39.0        tbd   E10+
# 15436         0.00          57.0        tbd      E
# 15438         0.00          47.0        tbd      T
# 15440         0.00           NaN        tbd    NaN
# 15443         0.00           NaN        tbd      E
# 15447         0.00           NaN        tbd      E
# 15448         0.00          69.0        tbd      E
# 15450         0.00           NaN        tbd      E
# 15454         0.00           NaN        tbd      E
# 15465         0.00           NaN        tbd      E
# 15474         0.00           NaN        tbd      E
# 15475         0.00           NaN        tbd      E
# 15501         0.00          68.0        tbd      E
# 15511         0.00           NaN        tbd      E
# 15513         0.00           NaN        tbd      E
# 15518         0.00           NaN        tbd      T
# 15523         0.00          51.0        tbd      T
# 15528         0.00           NaN        tbd      E
# 15531         0.00          38.0        tbd   E10+
# 15534         0.00           NaN        tbd      E
# 15540         0.00          77.0        tbd      E
# 15544         0.00          30.0        tbd      E
# 15565         0.00           NaN        tbd      E
# 15566         0.00           NaN        tbd      E
# 15574         0.00          70.0        tbd      E
# 15575         0.00          57.0        tbd   E10+
# 15577         0.00           NaN        tbd   E10+
# 15579         0.00          59.0        tbd      E
# 15583         0.00          68.0        tbd      E
# 15587         0.00           NaN        tbd    NaN
# 15606         0.00           NaN        tbd      E
# 15608         0.00           NaN        tbd      E
# 15622         0.00          76.0        tbd    NaN
# 15635         0.00          72.0        tbd      E
# 15637         0.00           NaN        tbd      E
# 15648         0.00           NaN        tbd      E
# 15662         0.00           NaN        tbd    NaN
# 15665         0.00           NaN        tbd      E
# 15671         0.00           NaN        tbd   E10+
# 15672         0.00          54.0        tbd      E
# 15684         0.00          39.0        tbd      E
# 15688         0.00          54.0        tbd      M
# 15689         0.00          65.0        tbd      E
# 15693         0.00          57.0        tbd      E
# 15697         0.00           NaN        tbd      E
# 15706         0.00          52.0        tbd      E
# 15708         0.00           NaN        tbd      E
# 15711         0.00          70.0        tbd      E
# 15715         0.00          57.0        tbd      E
# 15717         0.00          58.0        tbd      E
# 15719         0.00           NaN        tbd      E
# 15731         0.00           NaN        tbd      E
# 15738         0.00           NaN        tbd      T
# 15746         0.00          52.0        tbd      T
# 15748         0.00           NaN        tbd    NaN
# 15749         0.00           NaN        tbd   E10+
# 15752         0.00          62.0        tbd   E10+
# 15755         0.00          73.0        tbd      E
# 15759         0.00          59.0        tbd      E
# 15766         0.00           NaN        tbd      E
# 15772         0.00           NaN        tbd      T
# 15786         0.00           NaN        tbd      T
# 15791         0.00           NaN        tbd      E
# 15792         0.00           NaN        tbd      E
# 15798         0.00           NaN        tbd      E
# 15800         0.00           NaN        tbd      T
# 15806         0.00           NaN        tbd      T
# 15815         0.00           NaN        tbd      E
# 15822         0.00          70.0        tbd      E
# 15824         0.00           NaN        tbd      T
# 15826         0.00           NaN        tbd      E
# 15841         0.00           NaN        tbd      T
# 15843         0.00          61.0        tbd      E
# 15850         0.00          76.0        tbd      T
# 15852         0.00          62.0        tbd      E
# 15861         0.00           NaN        tbd      E
# 15868         0.00          60.0        tbd      E
# 15880         0.00          38.0        tbd      E
# 15885         0.00           NaN        tbd      E
# 15888         0.00          66.0        tbd      E
# 15891         0.00           NaN        tbd    NaN
# 15893         0.00          59.0        tbd      E
# 15894         0.00          59.0        tbd      E
# 15895         0.00          64.0        tbd      E
# 15897         0.00           NaN        tbd    NaN
# 15906         0.00          60.0        tbd      E
# 15907         0.00          59.0        tbd      T
# 15910         0.00          65.0        tbd   E10+
# 15913         0.00           NaN        tbd      E
# 15922         0.00          57.0        tbd      E
# 15923         0.00           NaN        tbd    NaN
# 15924         0.00          60.0        tbd   E10+
# 15925         0.00          31.0        tbd      E
# 15944         0.00           NaN        tbd    NaN
# 15950         0.00          66.0        tbd      T
# 15959         0.00          76.0        tbd      E
# 15963         0.00          40.0        tbd      T
# 15966         0.00          50.0        tbd      T
# 15975         0.00           NaN        tbd    NaN
# 15979         0.00           NaN        tbd      E
# 15983         0.00          64.0        tbd      T
# 15987         0.00           NaN        tbd      T
# 15991         0.00           NaN        tbd      E
# 16000         0.00           NaN        tbd      E
# 16004         0.00           NaN        tbd   E10+
# 16013         0.00           NaN        tbd      M
# 16014         0.00          68.0        tbd      E
# 16017         0.00           NaN        tbd      E
# 16020         0.00           NaN        tbd      E
# 16028         0.00           NaN        tbd      E
# 16042         0.00           NaN        tbd      E
# 16044         0.00           NaN        tbd      E
# 16053         0.00          35.0        tbd   E10+
# 16058         0.00          67.0        tbd      E
# 16061         0.00           NaN        tbd      E
# 16067         0.00           NaN        tbd   E10+
# 16076         0.00           NaN        tbd   E10+
# 16093         0.00           NaN        tbd    NaN
# 16119         0.00           NaN        tbd      E
# 16130         0.00          48.0        tbd      T
# 16134         0.00          72.0        tbd      E
# 16144         0.00           NaN        tbd      E
# 16165         0.00           NaN        tbd      E
# 16169         0.00           NaN        tbd      E
# 16172         0.00           NaN        tbd      E
# 16176         0.00           NaN        tbd      E
# 16178         0.00          58.0        tbd      E
# 16179         0.00           NaN        tbd      E
# 16182         0.00           NaN        tbd      T
# 16195         0.00           NaN        tbd      E
# 16200         0.00           NaN        tbd   E10+
# 16211         0.00           NaN        tbd      E
# 16214         0.00           NaN        tbd   E10+
# 16216         0.00           NaN        tbd    NaN
# 16226         0.00          71.0        tbd      E
# 16237         0.00           NaN        tbd      E
# 16238         0.00           NaN        tbd    NaN
# 16239         0.00          63.0        tbd      T
# 16243         0.00           NaN        tbd   E10+
# 16248         0.00           NaN        tbd      T
# 16253         0.00           NaN        tbd      E
# 16254         0.00           NaN        tbd      E
# 16259         0.00          48.0        tbd      T
# 16266         0.00           NaN        tbd      E
# 16267         0.00           NaN        tbd      T
# 16268         0.00           NaN        tbd   E10+
# 16285         0.00           NaN        tbd      E
# 16288         0.00           NaN        tbd   E10+
# 16290         0.00          56.0        tbd      T
# 16301         0.00           NaN        tbd      T
# 16304         0.00          65.0        tbd      E
# 16312         0.00           NaN        tbd      E
# 16318         0.00          23.0        tbd      E
# 16319         0.00           NaN        tbd      M
# 16328         0.00          37.0        tbd      E
# 16339         0.00          52.0        tbd      E
# 16340         0.00           NaN        tbd      E
# 16346         0.00           NaN        tbd   E10+
# 16359         0.00           NaN        tbd    NaN
# 16364         0.00           NaN        tbd      T
# 16373         0.00          43.0        tbd   E10+
# 16386         0.00          76.0        tbd      T
# 16394         0.00           NaN        tbd   E10+
# 16402         0.00          86.0        tbd      E
# 16404         0.00           NaN        tbd      E
# 16409         0.00          63.0        tbd      E
# 16421         0.00           NaN        tbd      E
# 16431         0.00           NaN        tbd      E
# 16436         0.00          49.0        tbd      E
# 16439         0.00          37.0        tbd      E
# 16442         0.00          44.0        tbd      T
# 16452         0.00          78.0        tbd   E10+
# 16457         0.00          55.0        tbd      E
# 16467         0.00          52.0        tbd      T
# 16470         0.00          42.0        tbd      E
# 16478         0.00           NaN        tbd   E10+
# 16485         0.00           NaN        tbd      T
# 16493         0.00          35.0        tbd   E10+
# 16494         0.00           NaN        tbd      E
# 16507         0.00          53.0        tbd      T
# 16520         0.00           NaN        tbd      T
# 16521         0.00           NaN        tbd      E
# 16534         0.00           NaN        tbd      E
# 16562         0.00           NaN        tbd      T
# 16568         0.00           NaN        tbd      E
# 16574         0.00           NaN        tbd      E
# 16577         0.00          40.0        tbd      T
# 16593         0.00           NaN        tbd      E
# 16599         0.00           NaN        tbd      E
# 16615         0.00           NaN        tbd      E
# 16626         0.00           NaN        tbd      T
# 16633         0.00           NaN        tbd   E10+
# 16638         0.00           NaN        tbd      E
# 16647         0.00           NaN        tbd      M
# 16650         0.00           NaN        tbd      T
# 16655         0.00           NaN        tbd    NaN
# 16669         0.00          72.0        tbd      T
# 16672         0.00           NaN        tbd      M
# 16688         0.00           NaN        tbd      T
# 16695         0.00          67.0        tbd      E
# 16697         0.00          53.0        tbd      E
# 16698         0.00          48.0        tbd      E
# 16704         0.00           NaN        tbd      E
# 16706         0.00           NaN        tbd      T

# %%
df_games['user_score'].replace('tbd', np.nan, inplace=True)
df_games['user_score'] = pd.to_numeric(df_games['user_score'], errors='coerce')

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   NA_sales         16713 non-null  float64
#  5   EU_sales         16713 non-null  float64
#  6   JP_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Изучил рейтинг игроков, считаю что заполнять пропуски в данном столбце не корректно, так как рейтинг понятие относительное и у каждого свое мнение.
# Особое внимание привлек рейтинг "tbd" - значит что "рейтинг пока не определен".

# %%
def total_sold(row):
    total_sales = row['NA_sales'] + row['EU_sales'] + row['JP_sales'] + row['other_sales']
    total = 0 
    for i in [total_sales]:
        if i > 0:
            total += i
    return total

# %%
df_games['total_sales'] = df_games.apply(total_sold, axis=1)
df_games.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    NA_sales  EU_sales  JP_sales  other_sales  critic_score  user_score rating  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0      E
# 1     29.08      3.58      6.81         0.77           NaN         NaN    NaN
# 2     15.68     12.76      3.79         3.29          82.0         8.3      E
# 3     15.61     10.93      3.28         2.95          80.0         8.0      E
# 4     11.27      8.89     10.22         1.00           NaN         NaN    NaN
# 5     23.20      2.26      4.22         0.58           NaN         NaN    NaN
# 6     11.28      9.14      6.50         2.88          89.0         8.5      E
# 7     13.96      9.18      2.93         2.84          58.0         6.6      E
# 8     14.44      6.94      4.70         2.24          87.0         8.4      E
# 9     26.93      0.63      0.28         0.47           NaN         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38
# 5        30.26
# 6        29.80
# 7        28.91
# 8        28.32
# 9        28.31

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int32
#  3   genre            16713 non-null  object
#  4   NA_sales         16713 non-null  float64
#  5   EU_sales         16713 non-null  float64
#  6   JP_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
#  11  total_sales      16713 non-null  float64
# dtypes: float64(7), int32(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# Создали функцию для подсчета "суммарных продаж по регионам", функция работает, продажи идут.

# %% [markdown]
# В столбце с рейтингом осталось много пропущенных значений..предлагаю заменить их на 'undefined' (неопределен)

# %%
#df_games['rating'] = df_games['rating'].fillna(undefined)
df_games['rating'].isna().sum()
# Out:
# 6764

# %%
df_games['rating'] = df_games['rating'].fillna('undefined')
df_games['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# В части анализа данных нам предстоит сделать следующие шаги:
# * Посмотреть, сколько игр выпускалось в разные годы. Ответить на вопрос: "Важны ли данные за все периоды?"
# * Посмотреть, как менялись продажи по платформам. Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. Ответить на вопрос: "За какой характерный срок появляются новые и исчезают старые платформы?"
# * Взять данные за соответствующий актуальный период. (актуальный период определить самостоятельно по результатам исследования предыдущих вопросов)
# * Ответить на вопрос: "Какие платформы лидируют по продажам, растут или падают?"
# * Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам
# * Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# * Соотнести выводы с продажами игр на других платформах.
# * Оценить общее распределение игр по жанрам.

# %%
df_games['year_of_release'].value_counts()
# Out:
# 2008    1427
# 2009    1426
# 2010    1255
# 2007    1197
# 2011    1136
# 2006    1006
# 2005     939
# 2002     829
# 2003     775
# 2004     762
# 2012     653
# 2015     606
# 2014     581
# 2013     544
# 2016     502
# 2001     482
# 1998     379
# 2000     350
# 1999     338
# 1997     289
# 3000     269
# 1996     263
# 1995     219
# 1994     121
# 1993      60
# 1981      46
# 1992      43
# 1991      41
# 1982      36
# 1986      21
# 1989      17
# 1983      17
# 1990      16
# 1987      16
# 1988      15
# 1985      14
# 1984      14
# 1980       9
# Name: year_of_release, dtype: int64

# %%
df_games['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %%
epoch_platforms = df_games.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum') #groupby(['platform','year_of_release']).agg({'total_sales':['sum']}).reset_index()
epoch_platforms.head()
# Out:
# platform          2600  3DO  3DS  DC  DS  GB  GBA  GC  GEN  GG  N64    NES  \
# year_of_release
# 1980             11.38  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  NaN    NaN
# 1981             35.68  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  NaN    NaN
# 1982             28.88  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  NaN    NaN
# 1983              5.84  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  NaN  10.96
# 1984              0.27  NaN  NaN NaN NaN NaN  NaN NaN  NaN NaN  NaN  50.08
#
# platform         NG  PC  PCFX  PS  PS2  PS3  PS4  PSP  PSV  SAT  SCD  SNES  \
# year_of_release
# 1980            NaN NaN   NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1981            NaN NaN   NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1982            NaN NaN   NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1983            NaN NaN   NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1984            NaN NaN   NaN NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# platform         TG16  WS  Wii  WiiU  X360  XB  XOne
# year_of_release
# 1980              NaN NaN  NaN   NaN   NaN NaN   NaN
# 1981              NaN NaN  NaN   NaN   NaN NaN   NaN
# 1982              NaN NaN  NaN   NaN   NaN NaN   NaN
# 1983              NaN NaN  NaN   NaN   NaN NaN   NaN
# 1984              NaN NaN  NaN   NaN   NaN NaN   NaN

# %%
top_platforms = ['PS2', 'DS', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA', 'GC', '3DS', 'PSV', 'PS4', 'N64', 'XOne', 'SNES']
df_top_platforms = df_games.query('platform == @top_platforms & year_of_release != 3000')
df_top_platforms_pivot = df_top_platforms.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(kind='bar', figsize=(15,10))
plt.ylabel("Количество")
plt.xlabel("Год выпуска")
# Out:
# Text(0.5, 0, 'Год выпуска')

# %% [markdown]
# Новые платформы появляются и теряют свою актуальность примерно каждые 5-7 лет. Считаю, что за "актуальный период" можно взять года с 2013-2016.

# %%
current_period = df_games.query('2013 <= year_of_release <= 2016').reset_index()

# %%
current_period.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum').plot(kind='bar', figsize=(15,10))
plt.ylabel("Количество")
plt.xlabel("Год выпуска")
# Out:
# Text(0.5, 0, 'Год выпуска')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Эта визуализация лучше предыдущей. 😉</font><br>
# <font color='DarkMagenta'>👉 А вот подписи по оси Y явно не хватает. 🙄 И это относится и к другим графикам проекта.</font>

# %%
current_period.pivot_table(index='name', columns='platform', values='total_sales', aggfunc='sum').boxplot(figsize=(15,10))
plt.ylabel("Количество")
plt.xlabel("Платформы")
# Out:
# Text(0.5, 0, 'Платформы')

# %%
big_platform = current_period.pivot_table(index='name', columns='platform', values='total_sales', aggfunc='sum').boxplot(figsize=(15,10))
plt.ylim(-0.2,1)
plt.ylabel("Количество")
plt.xlabel("Платформы")
# Out:
# Text(0.5, 0, 'Платформы')

# %% [markdown]
# Судя по графикам, особой популярностью пользуется консоль нового поколения - PS4. Она уверенно захватывает рынок, но ее предшественник, PS3 все еще не сдает позиции благодаря тому, что PlayStation все еще занимается поддержкой данной консоли и выпуском актуальных игр. ХOne проиграл в гонке с PS4.

# %% [markdown]
# Изучим, как влияют на продажи определенной платформы отзывы пользователей и критиков.

# %%
current_period.query('platform == "PS4"').plot(x='total_sales', y='user_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='user_score'>

# %%
current_period.query('platform == "PS4"').plot(x='total_sales', y='critic_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='critic_score'>

# %% [markdown]
# На графике прослеживается зависимость продаж от оценок, с увеличением оценок растут продажи. Оценка пользователей от 6 - 9  влияет сильней на продажи некоторых игр, чем оценки критиков. Но при оценках критиков от 70 баллов и выше продажи идут больше, чем от оценок пользователей.

# %% [markdown]
# Посчитаем общую корреляцию для всех продаж:

# %%
df_games[['total_sales', 'critic_score', 'user_score']].corr()
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.245507    0.088179
# critic_score     0.245507      1.000000    0.580878
# user_score       0.088179      0.580878    1.000000

# %% [markdown]
# Присутствует положительная корреляция продаж от мнения критиков, а вот от пользователей она очень маленькая..возможно это потому что оценок пользователей и так было меньше, так еще и рейтинг "tbd" мы заменили на Nan..
# Хорошая положительная корреляция от критиков - к пользователям, но сами пользователи не охотно ставят оценки продуктам..

# %% [markdown]
# Теперь посмотрим на корреляцию для платформы PS4:

# %%
PS4 = current_period.query('platform == "PS4"')
PS4['user_score'] = pd.to_numeric(PS4['user_score'], errors='coerce')
PS4[['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# C:\Users\dosy7\AppData\Local\Temp/ipykernel_7716/855295291.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PS4['user_score'] = pd.to_numeric(PS4['user_score'], errors='coerce')
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.406568   -0.031957
# critic_score     0.406568      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000

# %% [markdown]
# Судя по рассчитанной корреляции для PS4, оценка пользователй вызывает отрицательную корреляцию, а критиков - положительную.

# %%
current_period.query('platform == "XOne"').plot(x='total_sales', y='user_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='user_score'>

# %%
current_period.query('platform == "XOne"').plot(x='total_sales', y='critic_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='critic_score'>

# %%
XOne = current_period.query('platform == "XOne"')
XOne['user_score'] = pd.to_numeric(XOne['user_score'], errors='coerce')
XOne[['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# C:\Users\dosy7\AppData\Local\Temp/ipykernel_7716/3527704109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   XOne['user_score'] = pd.to_numeric(XOne['user_score'], errors='coerce')
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.416998   -0.068925
# critic_score     0.416998      1.000000    0.472462
# user_score      -0.068925      0.472462    1.000000

# %%
current_period.query('platform == "PC"').plot(x='total_sales', y='user_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='user_score'>

# %%
current_period.query('platform == "PC"').plot(x='total_sales', y='critic_score', kind='scatter', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='total_sales', ylabel='critic_score'>

# %%
PC = current_period.query('platform == "PC"')
PC['user_score'] = pd.to_numeric(PC['user_score'], errors='coerce')
PC[['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# C:\Users\dosy7\AppData\Local\Temp/ipykernel_7716/1210266853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PC['user_score'] = pd.to_numeric(PC['user_score'], errors='coerce')
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.196030   -0.093842
# critic_score     0.196030      1.000000    0.429562
# user_score      -0.093842      0.429562    1.000000

# %%
current_period.pivot_table(index='name', columns='genre', values='total_sales', aggfunc='sum').boxplot(figsize=(15,10))
plt.ylim(-0.2,5)
plt.ylabel("Количество")
plt.xlabel("Жанры")
# Out:
# Text(0.5, 0, 'Жанры')

# %% [markdown]
# Мы построили диаграммы размаха по всем жанрам игр. Особенно выделяются "Шутеры", их можно считать безоговорычным лидером на рынке продаж. ИХ медианное значение в иной момент выше выбросов некоторых жанров! "Гонки", "Платформеры" и "Спорт" идут следом, но им еще оочень далеко..
# Жанр с самым низким показателем - "Приключения". Скамем так, чтоб рассмотреть значения в этом жанре по лучше, необходимо использовать микроскоп..
# "Активные" игры выделяются тем, что у них огромное количетво выбросов.

# %% [markdown]
# Делая вывод по продажам и оценке пользователей/критиков можно сказать:
# * Общая корреляция - положительная;
# * PS4 имеет наименьшую отрицательную (но все же отрицательную) корреляцию продаж от оценок пользователей, продажи от оценок критиков - положительная корреляция;
# * ХOne имеет меньшую популярность, но суть остается такая же, чем выше оценка у продукта - тем чаще его покупают;
# * Продукт на PC имеет меньшую цену, чем на платформы PS и Xbox, а пользователи чаще ставят оценки от 6 - 8, чем на других платформах.

# %% [markdown]
# ### Итог по анализу данных:
# Проведя исследовательский анализ полученных данных, можно выделить следующее:
#
# * Самое продуктивное время в геймдеве с 2007 - 2011 годы, пик в 2008;
# * Судя по таблице, самое большое колличество продукта было произведено на платформе PS2, но для нашего исследования она не годится..слишком давно ушла "на покой";
# * "Актуальный период" для исследования выбран - с 2013 по 2016 год;
# * Актуальные платформы в актуальный период:
#     * PS4 --- топ 1
#     * PS3
#     * XOne
#     * PC
#     * 3DS
#     * PSV
# * Общая корреляция между продажами и отзывами критиков/пользователей за актуальный период - положительная, а вот высчитывая корреляцию для отдельных платформ, корреляция от пользовательских оценок становится отрицательной;
# * Судя по диаграмме размаха самый прибольный жанр игр - "Шутер", а самый не прибыльный - "Приключения".

# %% [markdown]
# ## Портрет пользователей отдельных регионов

# %%
user_NA = current_period.groupby('platform')['NA_sales'].sum()
user_NA.sort_values(ascending = False).head()
# Out:
# platform
# PS4     108.74
# XOne     93.12
# X360     81.66
# PS3      63.50
# 3DS      38.20
# Name: NA_sales, dtype: float64

# %%
user_NA.sort_values(ascending = False).head().plot(y='platform', kind='pie')
# Out:
# <AxesSubplot:ylabel='NA_sales'>

# %%
user_EU = current_period.groupby('platform')['EU_sales'].sum()
user_EU.sort_values(ascending = False).head()
# Out:
# platform
# PS4     141.09
# PS3      67.81
# XOne     51.59
# X360     42.52
# 3DS      30.96
# Name: EU_sales, dtype: float64

# %%
user_EU.sort_values(ascending = False).head().plot(y='platform', kind='pie')
# Out:
# <AxesSubplot:ylabel='EU_sales'>

# %%
user_JP = current_period.groupby('platform')['JP_sales'].sum()
user_JP.sort_values(ascending = False).head()
# Out:
# platform
# 3DS     67.81
# PS3     23.35
# PSV     18.59
# PS4     15.96
# WiiU    10.88
# Name: JP_sales, dtype: float64

# %%
user_JP.sort_values(ascending = False).head().plot(y='platform', kind='pie')
# Out:
# <AxesSubplot:ylabel='JP_sales'>

# %%
current_period.pivot_table(index='platform', values='NA_sales', aggfunc='sum').sort_values(by='NA_sales', ascending = False).head().plot(kind='bar', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
current_period.pivot_table(index='platform', values='EU_sales', aggfunc='sum').sort_values(by='EU_sales', ascending = False).head().plot(kind='bar', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
current_period.pivot_table(index='platform', values='JP_sales', aggfunc='sum').sort_values(by='JP_sales', ascending = False).head().plot(kind='bar', figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
current_period['rating'].value_counts()
# Out:
# undefined    977
# M            369
# T            333
# E            302
# E10+         252
# Name: rating, dtype: int64

# %%
top_rating_in_NA = current_period.groupby('rating')['NA_sales'].sum()
top_rating_in_NA.sort_values(ascending = False).head()
# Out:
# rating
# M            165.21
# undefined     89.42
# E             79.05
# E10+          54.24
# T             49.79
# Name: NA_sales, dtype: float64

# %%
top_rating_in_NA.sort_values(ascending = False).head().plot(y='genre', kind='pie')
# Out:
# <AxesSubplot:ylabel='NA_sales'>

# %%
top_rating_in_EU = current_period.groupby('rating')['EU_sales'].sum()
top_rating_in_EU.sort_values(ascending = False).head()
# Out:
# rating
# M            145.32
# E             83.36
# undefined     78.91
# E10+          42.69
# T             41.95
# Name: EU_sales, dtype: float64

# %%
top_rating_in_EU.sort_values(ascending = False).head().plot(y='genre', kind='pie')
# Out:
# <AxesSubplot:ylabel='EU_sales'>

# %%
top_rating_in_JP = current_period.groupby('rating')['JP_sales'].sum()
top_rating_in_JP.sort_values(ascending = False).head()
# Out:
# rating
# undefined    85.05
# T            20.59
# E            15.14
# M            14.11
# E10+          5.89
# Name: JP_sales, dtype: float64

# %%
top_rating_in_JP.sort_values(ascending = False).head().plot(y='genre', kind='pie')
# Out:
# <AxesSubplot:ylabel='JP_sales'>

# %%
# Комментарий ревьюера
temp = current_period.copy()
print(temp.rating.isna().sum(), temp.rating.isna().sum()/len(temp))
temp.rating.value_counts()
# Out:
# 0 0.0
# undefined    977
# M            369
# T            333
# E            302
# E10+         252
# Name: rating, dtype: int64

# %%
top_genre_in_NA = current_period.groupby('genre')['NA_sales'].sum()
top_genre_in_NA.sort_values(ascending = False).head()
# Out:
# genre
# Action          126.05
# Shooter         109.74
# Sports           65.27
# Role-Playing     46.40
# Misc             27.49
# Name: NA_sales, dtype: float64

# %%
top_genre_in_NA.sort_values(ascending = False).head().plot(y='genre', kind='pie')
plt.title('Топ-5 жанров в Штатах')
# Out:
# Text(0.5, 1.0, 'Топ-5 жанров в Штатах')

# %%
current_period.pivot_table(index='platform', columns='genre', values='NA_sales', aggfunc='sum').plot(kind='bar', figsize=(15,10))
plt.ylabel("Количество продаж в NA регионе")
plt.xlabel("Жанры на платформах")
# Out:
# Text(0.5, 0, 'Жанры на платформах')

# %%
top_genre_in_EU = current_period.groupby('genre')['EU_sales'].sum()
top_genre_in_EU.sort_values(ascending = False).head()
# Out:
# genre
# Action          118.13
# Shooter          87.86
# Sports           60.52
# Role-Playing     36.97
# Racing           20.19
# Name: EU_sales, dtype: float64

# %%
top_genre_in_EU.sort_values(ascending = False).head().plot(x='genre', kind='pie')
plt.title('Топ-5 жанров в Европе')
# Out:
# Text(0.5, 1.0, 'Топ-5 жанров в Европе')

# %%
current_period.pivot_table(index='platform', columns='genre', values='EU_sales', aggfunc='sum').plot(kind='bar', figsize=(15,10))
plt.ylabel("Количество продаж в EU регионе")
plt.xlabel("Жанры на платформах")
# Out:
# Text(0.5, 0, 'Жанры на платформах')

# %%
top_genre_in_JP = current_period.groupby('genre')['JP_sales'].sum()
top_genre_in_JP.sort_values(ascending = False).head()
# Out:
# genre
# Role-Playing    51.04
# Action          40.49
# Misc             9.20
# Fighting         7.65
# Shooter          6.61
# Name: JP_sales, dtype: float64

# %%
top_genre_in_JP.sort_values(ascending = False).head().plot(y='genre', kind='pie')
plt.title('Топ-5 жанров в Японии')
# Out:
# Text(0.5, 1.0, 'Топ-5 жанров в Японии')

# %%
current_period.pivot_table(index='platform', columns='genre', values='JP_sales', aggfunc='sum').plot(kind='bar', figsize=(15,10))
plt.ylabel("Количество продаж в JP регионе")
plt.xlabel("Жанры на платформах")
# Out:
# Text(0.5, 0, 'Жанры на платформах')

# %% [markdown]
# Подводя итоге портрета классического пользователя в отдельном регионе, можно выделить следующие пункты:
# * PS4 лидирует во всех позициях в Европе и Америке, Япония больше приверженец портативной приставки 3DS;
# * В Америке пользователей XOne не сильно меньше, но все же бокс проигрывает в продажах, в Европе его показатели еще хуже, там люди все еще верят и любят PS3, больше чем XOne (лидер все тот же PS4);
# * Пользователи из США и Европы предпочитают вкладывать свои деньги в игры рейтингом М (для взрослых, старше 17 лет), в Японии -  ESRB рейтинг не выставляется, по этому у них на первом месте идут "игры без рейтинга";
# * По части игровых жанров, NA и EU, опять же, схожи..пользователи охотнее играют в "Активные" и "Стрелялки", Япония опять отличилась и у них топ 1 занимают "Ролевые игры".

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Гипотезы для проверки:
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Формулируем гипотезы для проверки средних пользовательских рейтингов ХOne и PC:
# * H0 - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * H1 - Средние пользовательские рейтинги платформ Xbox One и PC - разные.

# %%
mean_X_rating = current_period[(current_period['platform'] == 'XOne') & (current_period['user_score'] > 0)]['user_score']

mean_PC_rating = current_period[(current_period['platform'] == 'PC') & (current_period['user_score'] > 0)]['user_score']

#& (current_period['user_score'] > 0)
# & (current_period['user_score'] > 0)
alpha = 0.05

result = st.ttest_ind(
    mean_X_rating, 
    mean_PC_rating)
print('p-значение:', result.pvalue)

if (result.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
print('Средний пользовательский рейтинг платформы XOne:', mean_X_rating.mean())
print('Средний пользовательский рейтинг платформы PC:', mean_PC_rating.mean())
# Out:
# p-значение: 0.14012658403611647
# Не отвергаем нулевую гипотезу
# Средний пользовательский рейтинг платформы XOne: 6.52142857142857
# Средний пользовательский рейтинг платформы PC: 6.269677419354836

# %% [markdown]
# Средние пользовательские рейтинги платформ - одинаковые, гипотеза подтвердилась.

# %% [markdown]
# Формулируем гипотезы для проверки средних пользовательских рейтингов жанров Action и Sports:
# * H0 - Средние пользовательские рейтинги жанров Action и Sports - не различаются;
# * H1 - Средний пользовательский рейтинг жанра Action и Sports разные.

# %%
mean_action_genre = current_period[(current_period['genre'] == 'Action') & (current_period['user_score'] > 0)]['user_score']

mean_sports_genre = current_period[(current_period['genre'] == 'Sports') & (current_period['user_score'] > 0)]['user_score']

alpha = 0.05

result = st.ttest_ind(
    mean_action_genre, 
    mean_sports_genre)
print('p-значение:', result.pvalue)

if (result.pvalue < alpha):
    print('Отвергаем нулевую гипотезу')
else:
    print('Не отвергаем нулевую гипотезу')
print('Средний пользовательский рейтинг жанра Action:', mean_action_genre.mean())
print('Средний пользовательский рейтинг жанра Sports:', mean_sports_genre.mean())
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу
# Средний пользовательский рейтинг жанра Action: 6.837532133676097
# Средний пользовательский рейтинг жанра Sports: 5.238124999999999

# %% [markdown]
# Гипотеза о рейтингах жанров Action и Sports - подтвердилась, они действительно разные!

# %% [markdown]
# ## Итог проделанной работы

# %% [markdown]
# Проведя все необходимые исследования, мы можем сделать выводы, что:
#
# * Самая перспективная платформа для развития и инвестиций - PS4;
# * "Золотое время" геймдева - 2007 - 2011, с пиком в 2008;
# * Пользователи из регионов NA и EU во многом похожи, но отличаются от пользователей из региона JP;
# * Пользователи из регионов NA и EU предпочитают игры с рейтингом М, а пользователи региона JP - игры без рейтинга, тк рейтинг  ESRB не распространяется на Японию;
# * Корреляция между продажами и отзывами критиков/пользователей за актуальный период - положительная;
#
# Потенциально лучшая перспектива для вложения:
#
# * PS4/XOne - Action/Shooter - NA/EU - rating-M;
# * 3DS - "Ролевые игры" - JP - ESRB в Японии не выставляется, у них своя организация.
#
# Проверка гипотез:
#
# * Гипотеза о рейтингах платформ - не подтвердилась, рейтинги оказались разные;
# * Гипотеза о рейтингах жанров - подтвердилась, рейтинги оказались разные.
#
# Рекомендация заказчику:
#
# * Предоставить более точное описание рейтингов игр;
# * Изучайте студии разработчиков напрямую;
